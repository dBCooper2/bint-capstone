# %% [markdown]
# ## $\color{red}{\text{Lecture Overview}}$
# 1. **Data visualization**
# 2. **Univariate charts for categorical data**
# 3. **Univariate charts for numeric data**

# %% [markdown]
# ## $\color{red}{\text{Data Visualization}}$
# 1. **Data visualization** is the use of charts to form a basic understanding of data
# 2. It is an effective part of any data analysis
# 3. Often, the data type will dictate which chart to use
#     - Example: Numeric, Categorical, etc.

# %% [markdown]
# ## $\color{red}{\text{Categories of Data Visualization}}$
# ### $\color{blue}{\text{Univariate and Multivariate Charts}}$
#
# 1. **Univariate charts**
#     - Displays the behavior of a single variable
# 2. **Multivariate charts**
#     - Displays the relationship between two or more variables

# %% [markdown]
# ## $\color{red}{\text{Import Required Packages}}$

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## $\color{red}{\text{Import Data}}$

# %%
df = pd.read_excel('/Users/dB/Documents/repos/github/bint-capstone/notebooks/data/hrData.xlsx', sheet_name='origData')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1465      Male
# 1466      Male
# 1467      Male
# 1468      Male
# 1469      Male
# Name: Gender, Length: 1470, dtype: object

# %% [markdown]
# ## $\color{red}{\text{Univariate Charts For Categorical Data}}$
# ### $\color{blue}{\text{Displaying Counts: Bar Plot}}$
#
# 1. For categorical data, there are limited options for visualization
# 2. Counts and percentages to display values in categories

# %% [markdown]
# ### $\color{green}{\text{Example 1}}$
#
# 1. Provide a bar graph that answers the following:
# 2. Comment on it
#     - What are the proportions of males and females in the HR dataset?

# %%
# value_counts() returns a table of the values in each column
# Normalize=True gives a pct
x = df['Gender'].value_counts(normalize=True) 
x
# Out:
# Gender
# Male      0.6
# Female    0.4
# Name: proportion, dtype: float64

# %%
count_m = df['Gender'].value_counts()['Male']
count_f = df['Gender'].value_counts()['Female']
count_m, count_f
# Out:
# (882, 588)

# %%
# Add a Title
plt.title('Percentage of Gender')
plt.ylabel('Percentage (0-1 Scale)')

# Color Sequences: Add Colors to the Chart (from L to R)
my_colors = list(['orange','blue']) # colors as a list
my_colors = list(['orange','#2142ab']) # colors with hex
my_colors = list('mc') # colors codes (magenta, cyan)

# instantiate a bar chart of our normalized gender data
x.plot(kind='bar', color=my_colors) 
plt.show() # shows only the plot

# %% [markdown]
# ### $\color{blue}{\text{Displaying Counts: Pie chart}}$
# 1. Displays relative sizes of each category
# 2. May be difficult to interpret if there are many categories

# %% [markdown]
# ### $\color{green}{\text{Example 2}}$
# 1. Provide a pie chart that answers the following:
# 2. Comment on it
#     - What is the educational background for individuals in the HR dataset?

# %%
x = df['EducationField'].value_counts(normalize=True)
x
# Out:
# EducationField
# Life Sciences       0.412245
# Medical             0.315646
# Marketing           0.108163
# Technical Degree    0.089796
# Other               0.055782
# Human Resources     0.018367
# Name: proportion, dtype: float64

# %%
plt.title('Education Field')
plt.ylabel('')
# This requires a lot of formatting to not overlap w/ plot
# plt.legend() 

my_colors = list('cmyrgb')
x.plot(kind='pie', colors=my_colors)

plt.show()

# %% [markdown]
# ## $\color{red}{\text{Univariate Charts For Numeric Data}}$
# ### $\color{blue}{\text{Histogram}}$
#
# 1. A histogram is useful for showing the distribution of data
# 2. It is possible to plot more than one (1) histogram on a chart

# %% [markdown]
# ### $\color{green}{\text{Example 3}}$
# 1. Provide a histogram of monthtly income and commment on it
# 2. Provide a histogram of monthly rate and comment on it
#     - Does anything stand out?

# %%
x = df['MonthlyIncome']

x.plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Alternatively...

# bins sets the bandwidth, alpha sets the opacity of the chart
x.hist(bins=50, alpha=.8)
plt.xlabel('Income')
plt.ylabel('# of Employees')
plt.title('Monthly Income :: Probability Distribution', fontsize=12)
plt.show()

# %% [markdown]
# Plotting Multiple Hists at Once:

# %%
x1 = df['MonthlyIncome']
x2 = df['MonthlyRate']

x1.plot(kind='hist', bins=50, alpha=.5)
x2.plot(kind='hist', bins=50, alpha=.5)

plt.legend(loc='upper right')
plt.xlabel('Income', fontsize=12)
plt.title('Histogram of Monthly Rate and Income')
plt.show()

# %% [markdown]
# **In this example, you need to be mindful of the scale! This is a bad chart, the variables you are plotting together need to make sense!**
#
# Also, look at how it automatically chose Orange/Blue, that's pretty neat.

# %% [markdown]
# ### $\color{blue}{\text{Density Plot}}$
# 1. Gives an estimation of probability density function
# 2. The **area** under the curve must sum to 1
# 3. The probability of a number between two values is the area under the curve of the two points

# %% [markdown]
# A density function is any function that returns a probability.

# %% [markdown]
# ### $\color{green}{\text{Example 4}}$
# 1. Provide a kde plot for the **PerformanceRating** variables
# 2. Comment on it

# %%
import scipy

x = df['PerformanceRating']
x.plot(kind='hist', alpha=.5)
x.plot(kind='kde')
plt.title('Performance Rating :: KDE')
plt.show()

# Choose Bin Sizes that give a mini-distribution of each Quartile!!!

# Use KDEPy, this isn't gonna work with plotting both in MPL...

# %% [markdown]
# ### $\color{blue}{\text{Box Plot}}$
# 1. Gives a "five point" summary of a variable
#     - Minimum
#     - 25th percentile
#     - 50th Percentile
#     - 75th Percentile
#     - Maximum
# 2. It also shows potential outliers

# %% [markdown]
# ### $\color{green}{\text{Example 5}}$
# 1. Provide a boxplot for the **HourlyRate** variable
# 2. Comment on it

# %%
x = df['HourlyRate']
df.boxplot(column=['MonthlyRate'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['HourlyRate','MonthlyRate'])
# Out:
# <Axes: >

# %% [markdown]
# You can keep doing this for any number of boxplots...
#
# Again, **scale matters!**
