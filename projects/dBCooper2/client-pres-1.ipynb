# %% [markdown]
# # Data Transformation
#
# ## Trevor Rowland :: 2-15-2025
#
# This notebook covers the techniques covered in Lectures 1-4 from class ([Link](<>)). This includes importing data, examining missing data, computing summary statistics and developing questions about the data. The dataset used will be game-level data from [Swar's](<link to gh>) [nba_api](<>) package, containing numerical data of home and away team statistics along with categorical data about which teams were playing.

# %% [markdown]
# ## 1. Importing Packages and Reading Data

# %% [markdown]
# The packages used can be installed via `pip install -r ~/project-root/projects/requirements.txt`.

# %%
import numpy as np
import pandas as pd
import missingno as msgo
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The data is hosted in a google drive folder, and can be accessed using the cell below

# %%
file_id = '1YWuRcRanepm2aI2asSWj-yRL8JubY7HA' # Obtained from the data's URL (https://drive/d/file-id/more-stuff)
url = f'https://drive.google.com/uc?id={file_id}' # Plugging the file_id into this URL allows it to be read in with pandas

df = pd.read_csv(url, encoding='utf-8') # the encoding='utf-8' param specifies how pandas reads in the csv and is required for this file

# %% [markdown]
# Let's get a quick look at the DataFrame with the `head()` function.

# %%
df.head(10)
# Out:
#     GAME_ID     HOME_ID HOME_NAME HOME_TRICODE HOME_MINUTES  \
# 0  40400407  1610612759     Spurs          SAS       240:00
# 1  40400406  1610612759     Spurs          SAS       240:00
# 2  40400405  1610612765   Pistons          DET       265:00
# 3  40400404  1610612765   Pistons          DET       240:00
# 4  40400403  1610612765   Pistons          DET       240:00
# 5  40400402  1610612759     Spurs          SAS       240:00
# 6  40400401  1610612759     Spurs          SAS       240:00
# 7  40400307  1610612748      Heat          MIA       240:00
# 8  40400306  1610612765   Pistons          DET       240:00
# 9  40400305  1610612748      Heat          MIA       240:00
#
#    HOME_FIELD_GOALS_MADE  HOME_FIELD_GOALS_ATTEMPTED  \
# 0                   29.0                        68.0
# 1                   31.0                        75.0
# 2                   37.0                        84.0
# 3                   41.0                        90.0
# 4                   40.0                        85.0
# 5                   29.0                        62.0
# 6                   34.0                        79.0
# 7                   32.0                        69.0
# 8                   36.0                        86.0
# 9                   36.0                        69.0
#
#    HOME_FIELD_GOALS_PERCENTAGE  HOME_THREE_POINTERS_MADE  \
# 0                        0.426                       7.0
# 1                        0.413                       8.0
# 2                        0.440                       2.0
# 3                        0.456                       2.0
# 4                        0.471                       3.0
# 5                        0.468                      11.0
# 6                        0.430                       4.0
# 7                        0.464                       2.0
# 8                        0.419                       7.0
# 9                        0.522                       3.0
#
#    HOME_THREE_POINTERS_ATTEMPTED  ...  AWAY_REBOUNDS_DEFENSIVE  \
# 0                           11.0  ...                     26.0
# 1                           28.0  ...                     27.0
# 2                            9.0  ...                     26.0
# 3                            9.0  ...                     32.0
# 4                           14.0  ...                     27.0
# 5                           24.0  ...                     27.0
# 6                           13.0  ...                     24.0
# 7                           11.0  ...                     28.0
# 8                           17.0  ...                     35.0
# 9                            8.0  ...                     27.0
#
#    AWAY_REBOUNDS_TOTAL  AWAY_ASSISTS  AWAY_STEALS  AWAY_BLOCKS  \
# 0                 34.0          17.0          8.0          6.0
# 1                 40.0          19.0          6.0          8.0
# 2                 45.0          20.0          3.0          3.0
# 3                 44.0          15.0          1.0          9.0
# 4                 37.0          16.0          7.0          3.0
# 5                 45.0          17.0          5.0          2.0
# 6                 35.0          15.0         12.0         10.0
# 7                 41.0          21.0          7.0          0.0
# 8                 40.0          15.0          1.0         10.0
# 9                 40.0          16.0          6.0          5.0
#
#    AWAY_TURNOVERS  AWAY_FOULS_PERSONAL  AWAY_POINTS  AWAY_PLUS_MINUS_POINTS  \
# 0             6.0                 24.0         74.0                    -7.0
# 1             5.0                 21.0         95.0                     9.0
# 2            16.0                 26.0         96.0                     1.0
# 3            17.0                 21.0         71.0                   -31.0
# 4            18.0                 21.0         79.0                   -17.0
# 5            13.0                 25.0         76.0                   -21.0
# 6            12.0                 19.0         69.0                   -15.0
# 7            13.0                 23.0         88.0                     6.0
# 8            16.0                 20.0         66.0                   -25.0
# 9            15.0                 23.0         76.0                   -12.0
#
#    SEASON_ID
# 0    2004-05
# 1    2004-05
# 2    2004-05
# 3    2004-05
# 4    2004-05
# 5    2004-05
# 6    2004-05
# 7    2004-05
# 8    2004-05
# 9    2004-05
#
# [10 rows x 48 columns]

# %% [markdown]
# And the size of the data can be found with the `pd.DataFrame.shape` attribute.

# %%
rownums, colnums = df.shape
print(f'there are {colnums} columns and {rownums} rows in the dataframe')
# Out:
# there are 48 columns and 27657 rows in the dataframe

# %% [markdown]
# ## Examining the Dataset I :: Checking for Missing Data
#
# The `missingno` package is an excellent way to quickly visualize the dataset and see what data are missing. The following cell creates the missingno `matrix` chart, where missing data are shown in the chart.

# %%
msgo.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# From the missingno chart, there appears to be no data missing. The main chart is fully filled with grey, indicating the chart has little to no missing data (missing data appears as whitespace). However, the frequency table to the right of the main chart has some spikes on it, indicating that there may be small amounts of missing data. An amplitude on the frequency chart indicates missing data, so some null values may exist. We can confirm this by counting the number of NA values in the data below.

# %%
df.isna().sum().sum() # Get the total number of missing vals
# Out:
# 598

# %% [markdown]
# At the time of writing this, we have 598 missing values in the data. We can see the breakdown of missing values by feature below.

# %%
nan_counts_df = pd.DataFrame({'Column': df.isna().sum().index, 'NaN Count': df.isna().sum().values})
nan_counts_df['NaN Percentage'] = (nan_counts_df['NaN Count'] / len(df)) * 100
nan_counts_df.sort_values(by='NaN Percentage', ascending=False).T
# Out:
#                           4             27           22  \
# Column          HOME_MINUTES  AWAY_MINUTES  HOME_POINTS
# NaN Count                 16            15           14
# NaN Percentage      0.057852      0.054236      0.05062
#
#                                          13                      23  \
# Column          HOME_FREE_THROWS_PERCENTAGE  HOME_PLUS_MINUS_POINTS
# NaN Count                                14                      14
# NaN Percentage                      0.05062                 0.05062
#
#                                  21              20           19           18  \
# Column          HOME_FOULS_PERSONAL  HOME_TURNOVERS  HOME_BLOCKS  HOME_STEALS
# NaN Count                        14              14           14           14
# NaN Percentage              0.05062         0.05062      0.05062      0.05062
#
#                           17  ...                          29  \
# Column          HOME_ASSISTS  ...  AWAY_FIELD_GOALS_ATTEMPTED
# NaN Count                 14  ...                          13
# NaN Percentage       0.05062  ...                    0.047004
#
#                                    28            26         25  \
# Column          AWAY_FIELD_GOALS_MADE  AWAY_TRICODE  AWAY_NAME
# NaN Count                          13            13         13
# NaN Percentage               0.047004      0.047004   0.047004
#
#                                     46           45       0        24  \
# Column          AWAY_PLUS_MINUS_POINTS  AWAY_POINTS  GAME_ID  AWAY_ID
# NaN Count                           13           13        0        0
# NaN Percentage                0.047004     0.047004      0.0      0.0
#
#                      1          47
# Column          HOME_ID  SEASON_ID
# NaN Count             0          0
# NaN Percentage      0.0        0.0
#
# [3 rows x 48 columns]

# %% [markdown]
# Now we have a detailed breakdown of what columns are missing by counts of missing values and percentages, sorted by the highest amounts of missing values.
#
# Given that the highest percentage of missing data is .05% of over 27,000 rows of data, we can safely remove the missing data without worrying about compromising our sample. This can be done with the `pd.DataFrame.dropna()` function.

# %%
df = df.dropna()

# %%
rownums_post_drop, colnums_post_drop = df.shape
print(f'there are now {colnums_post_drop} columns and {rownums_post_drop} rows in the DataFrame vs. {rownums} rows initially.')
# Out:
# there are now 48 columns and 27639 rows in the DataFrame vs. 27657 rows initially.

# %% [markdown]
# ## Examining the Data II :: Summary Statistics
#
# Now that the data has been cleaned, we can examine the summary statistics of the dataset to begin forming observations and hypotheses.

# %%
summ_stats_df = df.drop(['GAME_ID','HOME_ID','AWAY_ID'], axis=1)
summ_stats_df.describe().rename({'25%':'1Q','50%':'median','75%':'3Q'}).T
# Out:
#                                   count        mean        std     min  \
# HOME_FIELD_GOALS_MADE           27639.0   38.735157   5.627938   1.000
# HOME_FIELD_GOALS_ATTEMPTED      27639.0   83.766055   8.248487   5.000
# HOME_FIELD_GOALS_PERCENTAGE     27639.0    0.463231   0.056759   0.200
# HOME_THREE_POINTERS_MADE        27639.0    8.787040   4.345167   0.000
# HOME_THREE_POINTERS_ATTEMPTED   27639.0   24.377401   9.717949   1.000
# HOME_THREE_POINTERS_PERCENTAGE  27639.0    0.357476   0.108043   0.000
# HOME_FREE_THROWS_MADE           27639.0   18.590542   6.365900   0.000
# HOME_FREE_THROWS_ATTEMPTED      27639.0   24.399761   7.907445   0.000
# HOME_FREE_THROWS_PERCENTAGE     27639.0    0.763126   0.100967   0.000
# HOME_REBOUNDS_OFFENSIVE         27639.0   10.847172   3.928657   0.000
# HOME_REBOUNDS_DEFENSIVE         27639.0   32.578530   5.596994   3.000
# HOME_REBOUNDS_TOTAL             27639.0   43.425703   6.694509   5.000
# HOME_ASSISTS                    27639.0   23.166757   5.322226   1.000
# HOME_STEALS                     27639.0    7.599081   2.948925   0.000
# HOME_BLOCKS                     27639.0    5.071746   2.608002   0.000
# HOME_TURNOVERS                  27639.0   13.701111   3.977531   0.000
# HOME_FOULS_PERSONAL             27639.0   20.539383   4.521487   0.000
# HOME_POINTS                     27639.0  104.847715  13.713613   3.000
# HOME_PLUS_MINUS_POINTS          27639.0    2.703933  13.546218 -68.000
# AWAY_FIELD_GOALS_MADE           27639.0   37.826984   5.598691   3.000
# AWAY_FIELD_GOALS_ATTEMPTED      27639.0   83.756359   8.297335   8.000
# AWAY_FIELD_GOALS_PERCENTAGE     27639.0    0.452317   0.055755   0.239
# AWAY_THREE_POINTERS_MADE        27639.0    8.609393   4.259183   0.000
# AWAY_THREE_POINTERS_ATTEMPTED   27639.0   24.353775   9.648438   1.000
# AWAY_THREE_POINTERS_PERCENTAGE  27639.0    0.350761   0.106592   0.000
# AWAY_FREE_THROWS_MADE           27639.0   17.773328   6.142119   0.000
# AWAY_FREE_THROWS_ATTEMPTED      27639.0   23.390752   7.576939   0.000
# AWAY_FREE_THROWS_PERCENTAGE     27639.0    0.760395   0.103735   0.000
# AWAY_REBOUNDS_OFFENSIVE         27639.0   10.566772   3.854435   0.000
# AWAY_REBOUNDS_DEFENSIVE         27639.0   31.628785   5.553095   1.000
# AWAY_REBOUNDS_TOTAL             27639.0   42.195557   6.601318   1.000
# AWAY_ASSISTS                    27639.0   21.888925   5.318018   2.000
# AWAY_STEALS                     27639.0    7.555773   2.923536   0.000
# AWAY_BLOCKS                     27639.0    4.612432   2.436830   0.000
# AWAY_TURNOVERS                  27639.0   13.954738   4.043679   0.000
# AWAY_FOULS_PERSONAL             27639.0   21.200441   4.739428   0.000
# AWAY_POINTS                     27639.0  102.036687  13.887248   8.000
# AWAY_PLUS_MINUS_POINTS          27639.0   -2.698072  13.538136 -73.000
#
#                                     1Q   median       3Q      max
# HOME_FIELD_GOALS_MADE           35.000   39.000   42.000   84.000
# HOME_FIELD_GOALS_ATTEMPTED      78.000   84.000   89.000  146.000
# HOME_FIELD_GOALS_PERCENTAGE      0.424    0.462    0.500    0.747
# HOME_THREE_POINTERS_MADE         6.000    8.000   12.000   42.000
# HOME_THREE_POINTERS_ATTEMPTED   17.000   23.000   31.000   97.000
# HOME_THREE_POINTERS_PERCENTAGE   0.286    0.357    0.429    1.000
# HOME_FREE_THROWS_MADE           14.000   18.000   23.000   51.000
# HOME_FREE_THROWS_ATTEMPTED      19.000   24.000   29.000   64.000
# HOME_FREE_THROWS_PERCENTAGE      0.700    0.769    0.833    1.000
# HOME_REBOUNDS_OFFENSIVE          8.000   11.000   13.000   44.000
# HOME_REBOUNDS_DEFENSIVE         29.000   32.000   36.000   55.000
# HOME_REBOUNDS_TOTAL             39.000   43.000   48.000   74.000
# HOME_ASSISTS                    20.000   23.000   27.000   60.000
# HOME_STEALS                      6.000    7.000    9.000   22.000
# HOME_BLOCKS                      3.000    5.000    7.000   20.000
# HOME_TURNOVERS                  11.000   13.000   16.000   32.000
# HOME_FOULS_PERSONAL             17.000   20.000   23.000   41.000
# HOME_POINTS                     95.000  104.000  114.000  211.000
# HOME_PLUS_MINUS_POINTS          -6.000    3.000   11.000   73.000
# AWAY_FIELD_GOALS_MADE           34.000   38.000   41.000   82.000
# AWAY_FIELD_GOALS_ATTEMPTED      78.000   84.000   89.000  149.000
# AWAY_FIELD_GOALS_PERCENTAGE      0.415    0.451    0.489    0.687
# AWAY_THREE_POINTERS_MADE         5.000    8.000   11.000   35.000
# AWAY_THREE_POINTERS_ATTEMPTED   17.000   23.000   31.000   90.000
# AWAY_THREE_POINTERS_PERCENTAGE   0.282    0.350    0.419    1.000
# AWAY_FREE_THROWS_MADE           13.000   17.000   22.000   52.000
# AWAY_FREE_THROWS_ATTEMPTED      18.000   23.000   28.000   64.000
# AWAY_FREE_THROWS_PERCENTAGE      0.696    0.765    0.833    1.000
# AWAY_REBOUNDS_OFFENSIVE          8.000   10.000   13.000   40.000
# AWAY_REBOUNDS_DEFENSIVE         28.000   31.000   35.000   60.000
# AWAY_REBOUNDS_TOTAL             38.000   42.000   47.000   81.000
# AWAY_ASSISTS                    18.000   22.000   25.000   60.000
# AWAY_STEALS                      5.000    7.000    9.000   23.000
# AWAY_BLOCKS                      3.000    4.000    6.000   19.000
# AWAY_TURNOVERS                  11.000   14.000   16.000   39.000
# AWAY_FOULS_PERSONAL             18.000   21.000   24.000   45.000
# AWAY_POINTS                     92.000  102.000  111.000  196.000
# AWAY_PLUS_MINUS_POINTS         -11.000   -3.000    6.000   68.000

# %% [markdown]
# This works, but a visual representation should be used to better see the distributions of the data.

# %%
numeric_cols = summ_stats_df.select_dtypes(include=['number'])
plt.figure(figsize=(24, 6))
sns.boxplot(data=numeric_cols)
plt.xticks(rotation=90) # rotate the tick labels

plt.title('Boxplots of Game-Level NBA Data')
plt.show()

# %% [markdown]
# This is good, but removing outliers and sorting the chart by some measures could help. Let's start by removing the outliers, then re-plotting with distributions sorted by variance.

# %%
def remove_outliers(df):
    cleaned_df = df.copy()
    for col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        cleaned_df[col] = df[col].mask((df[col] < lower_bound) | (df[col] > upper_bound), np.nan)
    return cleaned_df

# %%
bp_df = remove_outliers(numeric_cols)

# Compute Variance and Sort Boxplots by variance
variances = numeric_cols.var().sort_values(ascending=False)
bp_df = bp_df[variances.index]

# Plot
plt.figure(figsize=(24, 6))
sns.boxplot(data=bp_df)
plt.xticks(rotation=90) # rotate the tick labels

plt.title('Boxplots of Game-Level NBA Data')
plt.show()

# %% [markdown]
# Now that the box plots have been cleaned up, the data can be examined to form questions and hypotheses. The following notes outline the next steps of the data analysis, where we will examine:
#
# ### High-Variance and Low-Variance Stats
#
# High-variance distributions are an area of interest to pursue, as they are the most **variable**, and could suggest inconsistencies in performance or playing style across teams. This could drive unpredictability in games. Inversely, low-variance statistics could indicate that these stats follow a pattern. These low-variance stats could be stable indicators of performance (good or bad) for a team.
#
# ### Skewed Distributions
#
# Skewed distributions could indicate extreme or uncommon events within the dataset. This could be an explosive performance by a player or team, and the tails of these distributions should be examined to determine what kind of event is occurring.
#
# ### Outlier-Prone Stats
#
# Outliers indicate rare events, and this dataset is full of them. In the plot including the outliers, we see that all of the boxplots have outliers, now we need to examine the filtered boxplots to see if there are any extrema within each distribution. This may be lumped in with skewed distributions as those also indicate rare events, although examining the outliers beyond the whiskers of each boxplot may be something to examine as well.
#
# ### Stats with Overlapping IQR
#
# When statistics have overlapping or equal Interquartile Ranges (IQR), it could either indicate redundancy or high correlation. By examining features with overlapping IQR, we can identify highly correlated variables, as well as redundant features that could lead to overfitting if used in a model for future presentations.
